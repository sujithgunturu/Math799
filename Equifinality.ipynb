# %% [markdown]
# <a href="https://colab.research.google.com/github/sujithgunturu/Math799/blob/master/Equifinality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
from sympy import *
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import pandas as pd


class Model:
    def __init__(self, Eqns):
        self.Eqns = Eqns
        self.t = None
        self.y0 = None
        self.par = None
        self.Env = None
    def new_soltimes(self,t):
        self.t=np.array(t)
    def new_ICs(self,y0):
        self.y0=np.array(y0)
    def new_params(self,params):
        self.par=np.array(params)
    def FetchEnviron(self,Environ):
        pass
    def GetEnvData(self,t):
        self.Edat=np.zeros(3)    
        
class Build_Jacobean:
    def __init__(self, system, statevars, statevars0, parameters):
      self.system = system
      self.statevars = statevars
      self.statevars0 = statevars0
      self.parameters = parameters
    def build_model(self):
      osumodel = Model(self.system)
      t = np.linspace(0,100, 100)
      osumodel.new_soltimes(t)
      osumodel.new_ICs(self.statevars0)
      osumodel.new_params(self.parameters)
      self.modelInstance = osumodel
      return osumodel
    def Run_Model(self, t):
      solution = dsolve(self.system,self.statevars ics = self.ics)
      return solution


      
class Generate_Fisher_Matrix:
    def __init__(self):
        pass
    def  Simulate(self):
        pass
    def Residuals(self):
        pass
    def du_dr_i(self):
        pass
    def da_dth8_k_div_a(self):
        pass
    def du_dth8_k(self):
        pass
    def dS_dth8_k(self):
        pass
    
    def S_matrix(self):
        pass
class Analyse_S_matrix:
    def __init__(self):
        pass
    def S_test(self):
        pass


# if __name__ == "__main__":
#    # create an object for class Build_Jacobean

# %%
S_xl,S_wt, theta_vr,theta_vd, theta_vo, theta_vs, theta_vq, theta_ps, theta_a, theta_pr, \
theta_pm, theta_tr, theta_td, theta_t0, theta_alpha, theta_el, theta_k, theta_sr,\
theta_sm, theta_rue, theta_m, theta_gx, theta_gb, theta_ts, k_i, k_m, k_e,t\
= symbols('S_xl S_wt theta_vr theta_vd theta_vo theta_vs theta_vq theta_ps \
theta_a theta_pr theta_pm theta_tr, theta_td, theta_t0, theta_alpha, theta_el, theta_k\
 theta_sr theta_sm theta_rue theta_m theta_gx theta_gb theta_ts k_i k_m k_e t')

S_vt = Function('S_vt')
S_lt = Function('S_lt')
S_at = Function('S_at')
S_wt = Function('S_at')
S_bt = Function('S_bt')
S_yt = Function('S_yt')
S_gt = Function('S_gt')

W_at = t**2
W_pt = t**2
W_at = t**2
W_st = t**2
W_nt = t**2
W_ht = t**2
W_pt2 = t**2
W_st = t**2
W_wt = t**2
W_rt = t**2
W_xt = t**2

# %%
dSvt_dt = Derivative(S_vt(t), t)
CV = Eq(dSvt_dt, (1 + exp(-1 * theta_vr * theta_vd))/(1+ (exp((-1 * theta_vr * (W_at - theta_vo + theta_vd)))) + ((exp( (theta_vr) * (W_at - theta_vo)  - 1)))))
f_vt = 1-theta_vs*(1- 1/(1+exp(-10/theta_vq*(S_vt(t) - theta_vq/2))))
f_pt = 1 - (1 - theta_ps * (1- (1 / (exp(-100 * (( S_at(t)/theta_a)-1) ))) )) * (1/(1 + exp(-theta_pr*(W_pt - theta_pm))))
d_tt = (1 + exp(-1 * theta_tr * theta_td)) / (1 + exp(-1 * theta_tr *(W_at - theta_t0 + theta_td) + exp((theta_tr * (W_at - theta_t0)) -1)))
dSat_dt = Derivative(S_at(t), t)
PA = Eq(dSat_dt,f_vt * f_pt * d_tt)
f_wt = 1 / (1 + exp((-np.log (99)/0.175)*(S_wt(t) - 0.175)))
dSlt_dt = S_lt(t).diff(t)
LAI = Eq(dSlt_dt, S_lt(t) * (d_tt*theta_alpha*f_wt*(1 - (1/(1+exp(-1* 100 * ((S_at(t)/theta_el) -1)))))* (1/exp(-1 * 100 *(exp(-1 * theta_k * S_lt(t))))) - (1/1+exp(-1 * theta_sr * (W_at/theta_sm - 1) ))))
dSbt_dt = S_bt(t).diff(t)
BIO = Eq(dSbt_dt, theta_rue * W_st * (1- exp(-1*theta_k * S_lt(t)) * f_wt* d_tt * (1- (1/ (1+exp(-100 * (S_at(t)/theta_m -1)*(1-(1/1+exp(-100*((1000 * S_yt(t)) /(theta_gx *S_gt(t)) -1)))) )) ) )))
dSgt_dt = S_gt(t).diff(t)
GN = Eq(dSgt_dt, dSbt_dt * theta_gb * (1 / (1 + exp(-1 * 100 * (S_at(t)/theta_a)-1))) * (1 - (1/(1+exp(-1 * 100 * (S_at(t)/theta_ts -1))))))
dSyt_dt = S_yt(t).diff(t)
Y = Eq(dSyt_dt, dSbt_dt * (1/ (1+exp(-1 * 100* (S_at(t)/theta_a -1)))))
D_t = (4098 * 0.6108 * exp((17.27 * W_at)/W_at+237.3))/(W_at + 237.3)**2
e_st = 0.6108 * (exp((17.27 * W_xt)/(W_xt + 237.3)) + exp((17.27 * W_nt)/W_nt +237.3)) /2 
e_at = e_st * W_ht * 0.01
gamma_t = 0.665 * 10**-3 * W_pt2
e0_t = ((0.408 * D_t * (W_st)) + (gamma_t * (900/(W_at + 273) * W_wt* (e_st - e_at))))/(D_t + gamma_t * (1+ 0.34 * W_wt))
#k_ct = k_i + (1-exp(-1 * theta_k * S_lt(t))) * (k_m - k_i + (k_i-k_e)/(exp(-1 * 100 * (S_at(t)/theta_a - 1) ) +1) ) - ( (k_i - k_e) / exp(-1 * 100 * (S_at(t)/theta_a -1) +1))
k_ct = 0.45 + (1-exp(-1 * theta_k * S_lt(t))) * (1.3 - 0.45 + (0.45-0.2)/(exp(-1 * 100 * (S_at(t)/theta_a - 1) ) +1) ) - ( (0.45 - 0.2) / exp(-1 * 100 * (S_at(t)/theta_a -1) +1))
e_ct = e0_t * k_ct
dSWt_dt = S_wt(t).diff(t)
SW = Eq(dSWt_dt, ((W_rt)/exp(-1 * 100 * (S_wt(t)/S_xl + 1) ) + 1) - (e_ct * f_wt))

system = [CV, PA, LAI, BIO, GN, Y, SW]
ics = {S_vt(0): 0, 
      S_at(0): 0,
      S_lt(0): 0,
      S_bt(0): 0,
      S_gt(0): 0,
      S_yt(0): 0,
      S_wt(0): 0}
theta_vr = -0.28
theta_vd = 5
theta_vo = 4
theta_vs = 1
theta_vq = 42
theta_ps = 0.8
theta_pr = 0.44
theta_pm = 10.67
theta_tr = 0.14
theta_td = -7.6
theta_t0 = 24
theta_alpha = 0.30
theta_el = 18
theta_k = 0.75
theta_sr = 10
theta_sm =35
theta_gx = 45
theta_m = 60
theta_gb = 20
theta_ts = 15
theta_rue = 1.15
theta_a = 36
Sxl = 150
# wrong, added for time being
k_i = 0.45
k_m = 1.3
k_e = 0.2
params = (theta_vr,theta_vd, theta_vo,
        theta_vs, theta_vq, theta_ps, 
        theta_pr, theta_pm, theta_tr, 
        theta_td, theta_t0,theta_alpha, 
        theta_el, theta_k, theta_sr, 
        theta_sm,theta_gx, theta_m, 
        theta_gb,theta_ts, theta_rue,
        theta_a, Sxl)
        #k_m, k_i,k_e,
funcs = [S_vt(t), S_at(t), S_lt(t), S_bt(t), S_gt(t), S_yt(t), S_wt(t)]
osumodel = Build_Jacobean(system, funcs, ics, params)
